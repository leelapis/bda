# %% [markdown]
# <div class="h1 display-1">Prof. Dr. Yan Li (Julian)</div>
#
#
# Email: leelapis@gmail.com

# %% [markdown]
# # Background

# %% [markdown]
# - 1999~2004, ***Xi'an Jiaotong Univeristy***, Bachelors in Engineering and Management
# - 2004~2010, ***Tsinghua University***, Ph.D. in Management

# %% [markdown]
# # Academic

# %% [markdown]
# - 2011~2012, City University of Hong Kong, Postdoc
# - 2012~ present, China University of Mining and Technology (Beijing)
#     - Assoc. Prof.
#     - Ph.D. supervisor

# %% [markdown]
# # Research Interests

# %% [markdown]
# - Online information governance
#     - fake (deepfake) inforamtion detection
#     - human's preferences

# %% [markdown]
# - Human and AI collaboration
#     - elderly digital gap
#     - autonomous negotiation

# %% [markdown]
# - Applied AI for domain-specific industrial applications
#     - retrieval-augmented generation (RAG)
#     - fine-tuning of large language models.
