# %% [markdown]
# # First

# %%
import pandas as pd

# %%
df = pd.DataFrame({'x':[1,2,3],'y':[2,4,6]},index=[0,1,2])
print(df)
# Out:
#    x  y
# 0  1  2
# 1  2  4
# 2  3  6

# %% [markdown]
# The business insights ....
